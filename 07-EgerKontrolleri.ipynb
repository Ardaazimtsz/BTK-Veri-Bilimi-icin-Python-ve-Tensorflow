# %% [markdown]
# **EĞER KONTROLLERİ**

# %%
if 3 > 1:
  print("Arda Azim Taşözü")
  print("İf Koşulu Sağlandı")
# Out:
# Arda Azim Taşözü
# İf Koşulu Sağlandı

# %%
if 3 > 4:
  print("Arda Azim Taşözü")
print("İf koşulu sağlanmadı")
# Out:
# İf koşulu sağlanmadı

# %%
x = 5

# %%
y = 4

# %%
if x > y:
  print("x, y'den daha büyükmüş")
# Out:
# x, y'den daha büyükmüş

# %%
if x > y:
  print("x, y'den daha büyükmüş")
elif y > x:
  print("y, x'den daha büyükmüş")
# Out:
# x, y'den daha büyükmüş

# %%
if x > y:
  print("x, y'den daha büyükmüş")
elif y > x:
  print("y, x'den daha büyükmüş")
elif x == y:
  print("x ve y birbirine eşitmiş")
# Out:
# x, y'den daha büyükmüş

# %%
if x > y:
  print("x, y'den daha büyükmüş")
elif y > x:
  print("y, x'den daha büyükmüş")
else:
  print("x ve y birbirine eşitmiş")
# Out:
# x, y'den daha büyükmüş

# %%
benimKahramanim = input("Süper kahraman seçiniz: ")
# Out:
# Süper kahraman seçiniz: Arda

# %%
if benimKahramanim == "Batman":
  print("Batman'i seçtiniz. tebrikler")
elif benimKahramanim == "Superman":
  print("Keşke Batman'i seçseydiniz")
else:
  print("Bu kim gerçekten bilmiyoruz.")
# Out:
# Bu kim gerçekten bilmiyoruz.

# %%
a = 10
b = 20
c = 30

# %%
if a > b and b > c:
  print("a,b'den büyük ve b, c'den büyük")
elif a < b and b < c:
  print("a, b'den küçük ve b, c'den küçük")
else:
  print("Bu koşullar tutmadı")
# Out:
# a, b'den küçük ve b, c'den küçük

# %%
karakterCanli = True

# %%
if karakterCanli == True:
  print("Oyun karakteriniz yaşıyor")
else:
  print("Oyun karakteriniz yaşamıyor")
# Out:
# Oyun karakteriniz yaşıyor

# %%
if karakterCanli:
  print("Oyun karakteriniz yaşıyor")
else:
  print("Oyun karakteriniz yaşamıyor")
# Out:
# Oyun karakteriniz yaşıyor

# %%
if not karakterCanli:
   print("Oyun karakteriniz yaşamıyor")

# %%
benimString = "Arda Azim Taşözü"

# %%
if benimString == "arda azim tasozu":
  print("Eşitmiş")
else:
  print("Eşit Değişlmiş")
# Out:
# Eşit Değişlmiş

# %%
if "Taşözü" in benimString:
  print("Varmış")
else:
  print("Yokmuş")
# Out:
# Varmış

# %%
benimListem = [10,20,30,40,50]

# %%
if 10 in benimListem:
  print("Evet var")
# Out:
# Evet var

# %%
benimSozluk = {"muz": 100, "elma": 200, "karpuz":500}

# %%
benimSozluk.keys()
# Out:
# dict_keys(['muz', 'elma', 'karpuz'])

# %%
if "muz" in benimSozluk.keys():
  print("Varmış")
# Out:
# Varmış

# %%
if 500 in benimSozluk.values():
  print("Varmış")
# Out:
# Varmış
