# %% [markdown]
# **Variables(Degiskenler)**

# %%
x = 5

# %%
y = 4

# %%
x * y
# Out:
# 20

# %%
x
# Out:
# 5

# %%
x = 6

# %%
x * y
# Out:
# 24

# %%
y * 10
# Out:
# 40

# %% [markdown]
# **Integer & Float**

# %%
benimDegiskenim = 10
benimDigerDegiskenim = 20

# %%
benimDegiskenim + benimDigerDegiskenim
# Out:
# 30

# %%
type(benimDegiskenim)
# Out:
# int

# %%
sonuc = benimDegiskenim / benimDigerDegiskenim

# %%
sonuc
# Out:
# 0.5

# %%
type(sonuc)
# Out:
# float

# %%
a = 3
b = 2

# %%
a / b
# Out:
# 1.5

# %%
pi = 3.14

# %%
type (pi)
# Out:
# float

# %%
a = 5

# %%
type(a)
# Out:
# int

# %%
a * pi
a + pi
a / pi
# Out:
# 1.592356687898089

# %%
a = 5
b = 4

# %%
sonuc = a + b

# %%
type(sonuc)
# Out:
# int

# %%
sonuc = a * b

# %%
type(sonuc)
# Out:
# int

# %% [markdown]
# **Matematiksel İşlemler**

# %%
x = 5
y = 3

# %%
x * y * 10
# Out:
# 150

# %%
x * x * x * x
# Out:
# 625

# %%
x ** 4
# Out:
# 625

# %%
# Remainder - Kalanını Bulmak
10 % 2
# Out:
# 0

# %%
11 % 2
# Out:
# 1

# %%
11 % 3
# Out:
# 2

# %%
kullanicininYasi = 10

# %%
kullanicininYasi * 5 / 3
# Out:
# 16.666666666666668

# %%
kullanicininYasi = input("Yaşınızı Giriniz: ")

# %%
kullanicininYasi
# Out:
# ''

# %%
type(kullanicininYasi)
# Out:
# str

# %%
kullanicininYasi * 5
# Out:
# ''

# %% [markdown]
# **String**

# %%
"Merhaba Dünya"
# Out:
# 'Merhaba Dünya'

# %%
x = "Merhaba Dünya"

# %%
type(x)
# Out:
# str

# %%
x.capitalize()
# Out:
# 'Merhaba dünya'

# %%
x.split()
# Out:
# ['Merhaba', 'Dünya']

# %%
benimString = "Arda Azim Taşözü"

# %%
benimString * 4
# Out:
# 'Arda Azim TaşözüArda Azim TaşözüArda Azim TaşözüArda Azim Taşözü'

# %%
benimInput = input("Yaşınızı Giriniz: ")

# %%
type(benimInput)
# Out:
# str

# %%
benimInInput = int(benimInput)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[48], line 1
# ----> 1 benimInInput = int(benimInput)
#
# ValueError: invalid literal for int() with base 10: ''

# %%
benimInInput / 3 * 5
# Out:
# 100.0

# %%
k = "Taşözü"

# %%
len(k)
# Out:
# 6

# %%
print("Merhaba \nDünya")
# Out:
# Merhaba
# Dünya

# %%
isimString = "Arda Azim Taşözü"

# %%
isimString
# Out:
# 'Arda Azim Taşözü'

# %% [markdown]
# **INDEX**

# %%
isimString[0]
# Out:
# 'A'

# %%
isimString[7]
# Out:
# 'i'

# %%
isimString[4]
# Out:
# ' '

# %%
isimString[-1]
# Out:
# 'ü'

# %%
isimString[-2]
# Out:
# 'z'

# %%
isimString[0] + isimString[-1]
# Out:
# 'Aü'

# %%
yeniString = "0123456789"

# %%
yeniString[5:]
# Out:
# '56789'

# %%
harfString = "abcdefgh"

# %%
harfString[3:]
# Out:
# 'defgh'

# %%
harfString[:3]
# Out:
# 'abc'

# %% [markdown]
# **Slicing**

# %%
gelenVeri = "AhmetinYaşi65"

# %%
gelenVeri[2:]
# Out:
# 'metinYaşi65'

# %%
gelenVeri[:-2]
# Out:
# 'AhmetinYaşi'

# %%
gelenVeri[-2:]
# Out:
# '65'

# %%
gelenVeri[2:4]
# Out:
# 'me'

# %%
## Step Size

# %%
gelenVeri[1:2]
# Out:
# 'h'

# %%
gelenVeri[1:6:2]
# Out:
# 'hei'

# %%
gelenVeri[::3]
# Out:
# 'Aenş5'

# %%
gelenVeri[::-1]
# Out:
# '56işaYnitemhA'

# %%
benimIsmım = "arda"

# %%
benimIsmım.capitalize()
# Out:
# 'Arda'

# %%
benimIsmım
# Out:
# 'arda'

# %%
benimYenimIsmım = benimIsmım.capitalize()

# %%
benimYenimIsmım
# Out:
# 'Arda'

# %%
benimTamIsmım = "Arda Azim Taşözü"

# %%
benimTamIsmım.split()
# Out:
# ['Arda', 'Azim', 'Taşözü']

# %%
benimTamIsmım.upper()
# Out:
# 'ARDA AZIM TAŞÖZÜ'

# %%
benimTamIsmım*3
# Out:
# 'Arda Azim TaşözüArda Azim TaşözüArda Azim Taşözü'

# %%
j = "5"
k = "50"

# %%
j+k
# Out:
# '550'
