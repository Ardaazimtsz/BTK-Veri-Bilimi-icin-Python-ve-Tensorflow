# %%
pip install pandas

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# **Seriler**

# %%
benimSozlugum  = {"Arda": 50, "Azim" : 60, "Tasozu": 70}

# %%
pd.Series(benimSozlugum)
# Out:
# Arda      50
# Azim      60
# Tasozu    70
# dtype: int64

# %%
benimYaslarim = [50,40,30]
benimIsımlerim = ["Arda","Azim","Tasozu"]

# %%
pd.Series(benimYaslarim)
# Out:
# 0    50
# 1    40
# 2    30
# dtype: int64

# %%
pd.Series(benimYaslarim,benimIsımlerim)
# Out:
# Arda      50
# Azim      40
# Tasozu    30
# dtype: int64

# %%
pd.Series(data=benimYaslarim, index=benimIsımlerim)
# Out:
# Arda      50
# Azim      40
# Tasozu    30
# dtype: int64

# %%
numpyDizisi = np.array([50,40,30])

# %%
numpyDizisi
# Out:
# array([50, 40, 30])

# %%
pd.Series(numpyDizisi,benimIsımlerim)
# Out:
# Arda      50
# Azim      40
# Tasozu    30
# dtype: int64

# %%
pd.Series(["Arda","Azim","Tasozu"],[1,2,3])
# Out:
# 1      Arda
# 2      Azim
# 3    Tasozu
# dtype: object

# %%
yarismaSonucu1 = pd.Series([10,5,1],["Arda","Azim","Tasozu"])

# %%
yarismaSonucu1
# Out:
# Arda      10
# Azim       5
# Tasozu     1
# dtype: int64

# %%
yarismaSonucu2 = pd.Series([20,10,5],["Arda","Azim","Tasozu"])

# %%
yarismaSonucu2
# Out:
# Arda      20
# Azim      10
# Tasozu     5
# dtype: int64

# %%
yarismaSonucu2["Arda"]
# Out:
# 20

# %%
sonSonuc = yarismaSonucu1 + yarismaSonucu2

# %%
sonSonuc
# Out:
# Arda      30
# Azim      15
# Tasozu     6
# dtype: int64

# %%
farkliYarisma = pd.Series([20,10,5],["Arda","Aziko","Tasozu"])

# %%
farkliSonuc = yarismaSonucu1 + farkliYarisma

# %%
farkliSonuc
# Out:
# Arda      30.0
# Aziko      NaN
# Azim       NaN
# Tasozu     6.0
# dtype: float64
