# %% [markdown]
# **Sözlükler**

# %% [markdown]
# **key-value pairing(anahtar kelime - değer işlemesi)**

# %%
benimYemeklerim = ["Elma", "Karpuz", "Muz"]

# %%
benimKalorilerim = [100,200,300]

# %%
benimKalorilerim[1]
# Out:
# 200

# %%
benimYemeklerim[1]
# Out:
# 'Karpuz'

# %%
#dictionary

# %%
benimSozluk = {"anahtarKelime" : "deger"}
type(benimSozluk)
# Out:
# dict

# %%
#benimSozluk[0]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-7-c77f3a207b66> in <cell line: 1>()
# ----> 1 benimSozluk[0]
#
# KeyError: 0

# %%
benimSozluk["anahtarKelime"]
# Out:
# 'deger'

# %%
benimYemekKaloriSozlugum = {"elma": 100, "Karpuz": 200, "Muz": 300}

# %%
benimYemekKaloriSozlugum["Muz"]
# Out:
# 300

# %%
benimYemekKaloriSozlugum["elma"] = 200

# %%
benimYemekKaloriSozlugum
# Out:
# {'elma': 200, 'Karpuz': 200, 'Muz': 300}

# %%
benimDegisikSozlugum = {1:"Arda", 2:"Berke"}

# %%
benimDegisikSozlugum[1]
# Out:
# 'Arda'

# %%
yeniDictionary = {"Anahtar1": 100, "Anahtar2": [10,20,30,40,4.5,"Arda"], "anahtar3": {"anahtar4": 4} }

# %%
yeniDictionary.keys()
# Out:
# dict_keys(['Anahtar1', 'Anahtar2', 'anahtar3'])

# %%
yeniDictionary.values()
# Out:
# dict_values([100, [10, 20, 30, 40, 4.5, 'Arda'], {'anahtar4': 4}])

# %%
yeniDictionary["Anahtar2"][5]
# Out:
# 'Arda'

# %%
yeniDictionary["anahtar3"]["anahtar4"]
# Out:
# 4
