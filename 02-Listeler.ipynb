# %% [markdown]
# **LISTELER**

# %%
benimString = "Arda Azim Taşözü"

# %%
benimString[0]
# Out:
# 'A'

# %%
# İmmutability & mutable // Değişmezlik

# %%
# benimString[0] = "B"

# %%
benimListem = [10,20,30,40]

# %%
type(benimListem)
# Out:
# list

# %%
benimNumaram = 10
BenimDiğerNumaram = 20

# %%
benimNumaraListem = [benimNumaram,BenimDiğerNumaram]

# %%
benimListem[3]
# Out:
# 40

# %%
benimListem
# Out:
# [10, 20, 30, 40]

# %%
benimListem[0] = 100

# %%
benimListem
# Out:
# [100, 20, 30, 40]

# %%
benimListem.append(50)

# %%
benimListem
# Out:
# [100, 20, 30, 40, 50]

# %%
benimListem.pop()
# Out:
# 50

# %%
benimListem
# Out:
# [100, 20, 30, 40]

# %%
benimListem.remove(40)

# %%
benimListem
# Out:
# [100, 20, 30]

# %%
# benimListem.remove(5)

# %%
benimListem.pop()
# Out:
# 30

# %%
benimListem
# Out:
# [100, 20]

# %%
benimListem.count(20)
# Out:
# 1

# %%
benimListem.append(20)

# %%
benimListem.count(20)
# Out:
# 2

# %%
benimStringListem = ["Arda","Azim","Taşözü"]
benimDigerListem = ["Berke","Girgin"]

# %%
benimStringListem + benimDigerListem
# Out:
# ['Arda', 'Azim', 'Taşözü', 'Berke', 'Girgin']

# %%
benimString *2
# Out:
# 'Arda Azim TaşözüArda Azim Taşözü'

# %%
# benimString / 2

# %%
# benimString - 1

# %%
karisikListe = [1,2,3.5,"arda",9]

# %%
type(karisikListe)
# Out:
# list

# %%
sonucum = karisikListe[0]

# %%
type(sonucum)
# Out:
# int

# %%
nestedList = [1,5,"Arda",4,[3,2,5,"z"]]

# %%
nestedList[3]
# Out:
# 4

# %%
nestedList[4]
# Out:
# [3, 2, 5, 'z']

# %%
nestedList[4][2]
# Out:
# 5

# %%
zDegiskenim = nestedList[4][3]

# %%
zDegiskenim
# Out:
# 'z'
