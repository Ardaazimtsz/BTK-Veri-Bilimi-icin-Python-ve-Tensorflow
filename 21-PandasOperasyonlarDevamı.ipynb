# %%
import numpy as np

# %%
import pandas as pd

# %%
sozluk1 = {"Isım": ["Ahmet","Mehmet","Zeynep","Arda"],
          "Spor": ["Kosu","Yuzme","Kosu","Basketbol"],
          "Kalori": [100,200,300,400]}

# %%
dataFrame1 = pd.DataFrame(sozluk1, index = [0,1,2,3])

# %%
dataFrame1
# Out:
#      Isım       Spor  Kalori
# 0   Ahmet       Kosu     100
# 1  Mehmet      Yuzme     200
# 2  Zeynep       Kosu     300
# 3    Arda  Basketbol     400

# %%
sozluk2 = {"Isım": ["Osman","Levent","Fatma","Atlas"],
          "Spor": ["Kosu","Yuzme","Kosu","Basketbol"],
          "Kalori": [200,300,400,100]}

# %%
dataFrame2 = pd.DataFrame(sozluk2,index = [4,5,6,7])

# %%
dataFrame2
# Out:
#     Isım       Spor  Kalori
# 4  Aziko       Kosu     300
# 5  Berke      Yuzme     400
# 6   Enes       Kosu     200
# 7  Ribiş  Basketbol     100

# %%
sozluk3 = {"Isım": ["Aziko","Berke","Enes","Ribiş"],
          "Spor": ["Kosu","Yuzme","Kosu","Basketbol"],
          "Kalori": [300,400,200,100]}

# %%
dataFrame3 = pd.DataFrame(sozluk3,index = [8,9,10,11])

# %%
dataFrame3
# Out:
#      Isım       Spor  Kalori
# 8   Aziko       Kosu     300
# 9   Berke      Yuzme     400
# 10   Enes       Kosu     200
# 11  Ribiş  Basketbol     100

# %% [markdown]
# # **Concatenation**

# %%
pd.concat([dataFrame1,dataFrame2,dataFrame3])
# Out:
#       Isım       Spor  Kalori
# 0    Ahmet       Kosu     100
# 1   Mehmet      Yuzme     200
# 2   Zeynep       Kosu     300
# 3     Arda  Basketbol     400
# 4    Aziko       Kosu     300
# 5    Berke      Yuzme     400
# 6     Enes       Kosu     200
# 7    Ribiş  Basketbol     100
# 8    Aziko       Kosu     300
# 9    Berke      Yuzme     400
# 10    Enes       Kosu     200
# 11   Ribiş  Basketbol     100

# %% [markdown]
# # #**Merge**

# %%
sozluk4 = {"Isım": ["Ahmet","Mehmet","Zeynep","Arda"],
          "Spor": ["Kosu","Yuzme","Kosu","Basketbol"]}

# %%
dataFrame4 = pd.DataFrame(sozluk4)

# %%
dataFrame4
# Out:
#      Isım       Spor
# 0   Ahmet       Kosu
# 1  Mehmet      Yuzme
# 2  Zeynep       Kosu
# 3    Arda  Basketbol

# %%
sozluk5 = {"Isım": ["Ahmet","Mehmet","Zeynep","Arda"],
          "Kalori": [100,200,300,400]}

# %%
dataFrame5 = pd.DataFrame(sozluk5)

# %%
dataFrame5
# Out:
#      Isım  Kalori
# 0   Ahmet     100
# 1  Mehmet     200
# 2  Zeynep     300
# 3    Arda     400

# %%
mergeDataFrame = pd.merge(dataFrame4,dataFrame5, on="Isım")

# %%
mergeDataFrame
# Out:
#      Isım       Spor  Kalori
# 0   Ahmet       Kosu     100
# 1  Mehmet      Yuzme     200
# 2  Zeynep       Kosu     300
# 3    Arda  Basketbol     400

# %%
maasSozluk = {"İsim": ["Arda","Azim","Tasozu","Berke"],
            "Departman": ["Yazılım","Satış","Pazarlama","Yazılım"],
              "Maas": [200,300,400,500]}

# %%
maasDataFrame = pd.DataFrame(maasSozluk)

# %%
maasDataFrame
# Out:
#      İsim  Departman  Maas
# 0    Arda    Yazılım   200
# 1    Azim      Satış   300
# 2  Tasozu  Pazarlama   400
# 3   Berke    Yazılım   500

# %%
maasDataFrame["Departman"]
# Out:
# 0      Yazılım
# 1        Satış
# 2    Pazarlama
# 3      Yazılım
# Name: Departman, dtype: object

# %%
maasDataFrame["Departman"].nunique()
# Out:
# 3

# %%
maasDataFrame["Departman"].value_counts()
# Out:
# Yazılım      2
# Satış        1
# Pazarlama    1
# Name: Departman, dtype: int64

# %%
def bruttenNete(maas):
  return maas*0.66

# %%
maasDataFrame["Maas"].apply(bruttenNete)
# Out:
# 0    132.0
# 1    198.0
# 2    264.0
# 3    330.0
# Name: Maas, dtype: float64

# %%
maasDataFrame.isnull()
# Out:
#     İsim  Departman   Maas
# 0  False      False  False
# 1  False      False  False
# 2  False      False  False
# 3  False      False  False

# %%
yeniBirVeri = {"Karakter Sinif": ["South Park","South Park","Simpson","Simpson","Simpson"],
               "Karakter Ismi": ["Cartman","Kenny","Homer","Bart","Bart"],
               "Karakter Yas": [9,10,11,12,13]}

# %%
yeniDF = pd.DataFrame(yeniBirVeri)

# %%
yeniDF
# Out:
#   Karakter Sınıf Karakter Ismi  Karakter Yas
# 0     South Park       Cartman             9
# 1     South Park         Kenny            10
# 2        Simpson         Homer            11
# 3        Simpson          Bart            12
# 4        Simpson          Bart            13

# %%
yeniDF.pivot_table(values = "Karakter Yas", index = ["Karakter Sinif","Karakter Ismi"])
# Out:
#                               Karakter Yas
# Karakter Sınıf Karakter Ismi
# Simpson        Bart                   12.5
#                Homer                  11.0
# South Park     Cartman                 9.0
#                Kenny                  10.0

# %%
yeniDF.pivot_table(values = "Karakter Yas", index = ["Karakter Sinif","Karakter Ismi"],aggfunc = np.sum)
# Out:
#                               Karakter Yas
# Karakter Sınıf Karakter Ismi
# Simpson        Bart                     25
#                Homer                    11
# South Park     Cartman                   9
#                Kenny                    10
