# %%
import pandas as pd
import numpy as np

# %%
data = np.random.randn(4,3)

# %%
data
# Out:
# array([[-1.0156857 , -0.69728267,  0.88125703],
#        [-0.12929008, -0.46778275, -1.22191236],
#        [ 0.7892169 ,  1.26112262, -0.69463228],
#        [-0.34325284, -0.45109786, -1.28948712]])

# %%
dataFrame = pd.DataFrame(data)

# %%
dataFrame
# Out:
#           0         1         2
# 0 -1.015686 -0.697283  0.881257
# 1 -0.129290 -0.467783 -1.221912
# 2  0.789217  1.261123 -0.694632
# 3 -0.343253 -0.451098 -1.289487
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# dataFrame[0].plot(kind='hist', bins=20, title=0)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# dataFrame[1].plot(kind='hist', bins=20, title=1)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# dataFrame[2].plot(kind='hist', bins=20, title=2)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# ...

# %%
dataFrame[0]
# Out:
# 0   -1.015686
# 1   -0.129290
# 2    0.789217
# 3   -0.343253
# Name: 0, dtype: float64

# %%
yeniDataFrame = pd.DataFrame(data,index=["Arda","Azim","Tasozu","Berke"],columns=["Maas","Yas","CS"])

# %%
yeniDataFrame
# Out:
#             Maas       Yas        CS
# Arda   -1.015686 -0.697283  0.881257
# Azim   -0.129290 -0.467783 -1.221912
# Tasozu  0.789217  1.261123 -0.694632
# Berke  -0.343253 -0.451098 -1.289487

# %%
yeniDataFrame["Yas"]
# Out:
# Arda     -0.697283
# Azim     -0.467783
# Tasozu    1.261123
# Berke    -0.451098
# Name: Yas, dtype: float64

# %%
yeniDataFrame [["Maas","Yas"]]
# Out:
#             Maas       Yas
# Arda   -1.015686 -0.697283
# Azim   -0.129290 -0.467783
# Tasozu  0.789217  1.261123
# Berke  -0.343253 -0.451098

# %%
# yeniDataFrame["Arda"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3801             try:
# -> 3802                 return self._engine.get_loc(casted_key)
#    3803             except KeyError as err:
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Arda'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
yeniDataFrame.loc["Arda"]
# Out:
# Maas   -1.015686
# Yas    -0.697283
# CS      0.881257
# Name: Arda, dtype: float64

# %%
yeniDataFrame.loc["Azim"]
# Out:
# Maas   -0.129290
# Yas    -0.467783
# CS     -1.221912
# Name: Azim, dtype: float64

# %%
yeniDataFrame.iloc[1]
# Out:
# Maas   -0.129290
# Yas    -0.467783
# CS     -1.221912
# Name: Azim, dtype: float64

# %%
yeniDataFrame["Maas"]
# Out:
# Arda     -1.015686
# Azim     -0.129290
# Tasozu    0.789217
# Berke    -0.343253
# Name: Maas, dtype: float64

# %%
yeniDataFrame["Emeklilik Yasi"] = yeniDataFrame["Yas"] + yeniDataFrame["Yas"]

# %%
yeniDataFrame
# Out:
#             Maas       Yas        CS  Emeklilik Yasi
# Arda   -1.015686 -0.697283  0.881257       -1.394565
# Azim   -0.129290 -0.467783 -1.221912       -0.935566
# Tasozu  0.789217  1.261123 -0.694632        2.522245
# Berke  -0.343253 -0.451098 -1.289487       -0.902196

# %%
yeniDataFrame.drop("Emeklilik Yasi", axis=1)
# Out:
#             Maas       Yas        CS
# Arda   -1.015686 -0.697283  0.881257
# Azim   -0.129290 -0.467783 -1.221912
# Tasozu  0.789217  1.261123 -0.694632
# Berke  -0.343253 -0.451098 -1.289487

# %%
yeniDataFrame.drop("Tasozu")
# Out:
#            Maas       Yas        CS  Emeklilik Yasi
# Arda  -1.015686 -0.697283  0.881257       -1.394565
# Azim  -0.129290 -0.467783 -1.221912       -0.935566
# Berke -0.343253 -0.451098 -1.289487       -0.902196

# %%
yeniDataFrame.drop("Emeklilik Yasi", axis = 1, inplace=True)

# %%
yeniDataFrame
# Out:
#             Maas       Yas        CS
# Arda   -1.015686 -0.697283  0.881257
# Azim   -0.129290 -0.467783 -1.221912
# Tasozu  0.789217  1.261123 -0.694632
# Berke  -0.343253 -0.451098 -1.289487

# %%
yeniDataFrame.loc["Arda"]
# Out:
# Maas   -1.015686
# Yas    -0.697283
# CS      0.881257
# Name: Arda, dtype: float64

# %%
yeniDataFrame.loc["Arda"]["Maas"]
# Out:
# -1.0156856952641256

# %%
yeniDataFrame.loc["Arda","Maas"]
# Out:
# -1.0156856952641256

# %%
yeniDataFrame
# Out:
#             Maas       Yas        CS
# Arda   -1.015686 -0.697283  0.881257
# Azim   -0.129290 -0.467783 -1.221912
# Tasozu  0.789217  1.261123 -0.694632
# Berke  -0.343253 -0.451098 -1.289487

# %%
boolenFrame = yeniDataFrame < 0

# %%
boolenFrame
# Out:
#          Maas    Yas     CS
# Arda     True   True  False
# Azim     True   True   True
# Tasozu  False  False   True
# Berke    True   True   True

# %%
yeniDataFrame[boolenFrame]
# Out:
#             Maas       Yas        CS
# Arda   -1.015686 -0.697283       NaN
# Azim   -0.129290 -0.467783 -1.221912
# Tasozu       NaN       NaN -0.694632
# Berke  -0.343253 -0.451098 -1.289487

# %%
yeniDataFrame[yeniDataFrame<0]
# Out:
#             Maas       Yas        CS
# Arda   -1.015686 -0.697283       NaN
# Azim   -0.129290 -0.467783 -1.221912
# Tasozu       NaN       NaN -0.694632
# Berke  -0.343253 -0.451098 -1.289487

# %%
yeniDataFrame[yeniDataFrame["Yas"] > 0]
# Out:
#             Maas       Yas        CS
# Tasozu  0.789217  1.261123 -0.694632
# <h4 class="colab-quickchart-section-title">Time series</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   counted = (series['Maas']
#                 .value_counts()
#               .reset_index(name='counts')
#               .rename({'index': 'Maas'}, axis=1)
#               .sort_values('Maas', ascending=True))
#   xs = counted['Maas']
#   ys = counted['counts']
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_0.sort_values('Maas', ascending=True)
# _plot_series(df_sorted, '')
# sns.despine(fig=fig, ax=ax)
# ...

# %%
yeniDataFrame.reset_index()
# Out:
#     index      Maas       Yas        CS
# 0    Arda -1.015686 -0.697283  0.881257
# 1    Azim -0.129290 -0.467783 -1.221912
# 2  Tasozu  0.789217  1.261123 -0.694632
# 3   Berke -0.343253 -0.451098 -1.289487

# %%
yeniDataFrame
# Out:
#             Maas       Yas        CS
# Arda   -1.015686 -0.697283  0.881257
# Azim   -0.129290 -0.467783 -1.221912
# Tasozu  0.789217  1.261123 -0.694632
# Berke  -0.343253 -0.451098 -1.289487

# %%
yeniIndeksListesi = ["Ard","Azi","Tsz","Brk"]

# %%
yeniDataFrame["Yeni Listesi"] = yeniIndeksListesi

# %%
yeniDataFrame
# Out:
#             Maas       Yas        CS Yeni Listesi
# Arda   -1.015686 -0.697283  0.881257          Ard
# Azim   -0.129290 -0.467783 -1.221912          Azi
# Tasozu  0.789217  1.261123 -0.694632          Tsz
# Berke  -0.343253 -0.451098 -1.289487          Brk

# %%
yeniDataFrame.set_index("Yeni Listesi")
# Out:
#                   Maas       Yas        CS
# Yeni Listesi
# Ard          -1.015686 -0.697283  0.881257
# Azi          -0.129290 -0.467783 -1.221912
# Tsz           0.789217  1.261123 -0.694632
# Brk          -0.343253 -0.451098 -1.289487

# %%
yeniDataFrame.set_index("Yeni Listesi", inplace = True)

# %%
yeniDataFrame
# Out:
#                   Maas       Yas        CS
# Yeni Listesi
# Ard          -1.015686 -0.697283  0.881257
# Azi          -0.129290 -0.467783 -1.221912
# Tsz           0.789217  1.261123 -0.694632
# Brk          -0.343253 -0.451098 -1.289487

# %%
yeniDataFrame.loc["Ard"]
# Out:
# Maas   -1.015686
# Yas    -0.697283
# CS      0.881257
# Name: Ard, dtype: float64

# %%
ilkIndeksler = ["Simpson","Simpson","Simpson","South Park","South Park","South Park"]

# %%
icIndeksler = ["Homer","Bart","Marge","Cartman","Kenny","Kyle"]

# %%
birlesmisIndeks = list(zip(ilkIndeksler,icIndeksler))

# %%
birlesmisIndeks
# Out:
# [('Simpson', 'Homer'),
#  ('Simpson', 'Bart'),
#  ('Simpson', 'Marge'),
#  ('South Park', 'Cartman'),
#  ('South Park', 'Kenny'),
#  ('South Park', 'Kyle')]

# %%
birlesmisIndeks = pd.MultiIndex.from_tuples(birlesmisIndeks)

# %%
birlesmisIndeks
# Out:
# MultiIndex([(   'Simpson',   'Homer'),
#             (   'Simpson',    'Bart'),
#             (   'Simpson',   'Marge'),
#             ('South Park', 'Cartman'),
#             ('South Park',   'Kenny'),
#             ('South Park',    'Kyle')],
#            )

# %%
benimCızgıFilmListem = [[40, "A"], [30, "B"], [30, "C"], [9, "D"], [11, "E"], [13, "F"]]

# %%
cizgiFilmNumpyDizisi = np.array(benimCızgıFilmListem)

# %%
cizgiDataFrame = pd.DataFrame(cizgiFilmNumpyDizisi, index = birlesmisIndeks,columns=["Yas","Meslek"])

# %%
cizgiDataFrame
# Out:
#                    Yas Meslek
# Simpson    Homer    40      A
#            Bart     30      B
#            Marge    30      C
# South Park Cartman   9      D
#            Kenny    11      E
#            Kyle     13      F

# %%
cizgiDataFrame.loc["Simpson"]
# Out:
#       Yas Meslek
# Homer  40      A
# Bart   30      B
# Marge  30      C

# %%
cizgiDataFrame.loc["South Park"].loc["Kenny"]
# Out:
# Yas       11
# Meslek     E
# Name: Kenny, dtype: object

# %%
cizgiDataFrame
# Out:
#                    Yas Meslek
# Simpson    Homer    40      A
#            Bart     30      B
#            Marge    30      C
# South Park Cartman   9      D
#            Kenny    11      E
#            Kyle     13      F

# %%
cizgiDataFrame.index.names= ["Film Adı", "İsim"]

# %%
cizgiDataFrame
# Out:
#                    Yas Meslek
# Film Adı   İsim
# Simpson    Homer    40      A
#            Bart     30      B
#            Marge    30      C
# South Park Cartman   9      D
#            Kenny    11      E
#            Kyle     13      F
