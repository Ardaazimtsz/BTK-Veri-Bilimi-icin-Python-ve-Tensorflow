# %%
benimListem = [10,20,30,40,50]

# %%
if 10 in benimListem:
  print("EVET İÇERİSİNDE MEVCUT")
# Out:
# EVET İÇERİSİNDE MEVCUT

# %%
benimListem[1] * 5 /3
# Out:
# 33.333333333333336

# %%
print("Döngü Başladı")
for numara in  benimListem:
  print(numara)
print("Döngü Bitti")
# Out:
# Döngü Başladı
# 10
# 20
# 30
# 40
# 50
# Döngü Bitti

# %%
print("Döngü Başladı")
for numara in  benimListem:
  print(numara *5/3)
print("Döngü Bitti")
# Out:
# Döngü Başladı
# 16.666666666666668
# 33.333333333333336
# 50.0
# 66.66666666666667
# 83.33333333333333
# Döngü Bitti

# %%
for num in benimListem:
  yeninumara = num *5 /3
  print(yeninumara)
# Out:
# 16.666666666666668
# 33.333333333333336
# 50.0
# 66.66666666666667
# 83.33333333333333

# %%
yeniListe = [1,2,3,4,5]

# %%
for rakam in yeniListe:
  if rakam % 2 == 0:
    print(rakam)
  if not rakam % 2 == 0:
    print("Numara 2'ye bölünmüyor")
# Out:
# Numara 2'ye bölünmüyor
# 2
# Numara 2'ye bölünmüyor
# 4
# Numara 2'ye bölünmüyor

# %%
yeniString = "Arda Azim Taşözü"

# %%
for harf in yeniString:
  print(harf)
# Out:
# A
# r
# d
# a
#
# A
# z
# i
# m
#
# T
# a
# ş
# ö
# z
# ü

# %%
benimTuple = (1,2,3,4,5)

# %%
for eleman in benimTuple:
  print(eleman)
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
koordinatListesi = [(10.2,15.2),(32.6,19.2),(40,23)]

# %%
type(koordinatListesi)
# Out:
# list

# %%
for eleman in koordinatListesi:
  print(eleman)
# Out:
# (10.2, 15.2)
# (32.6, 19.2)
# (40, 23)

# %%
for (x,y) in koordinatListesi:
  print(x,y)
# Out:
# 10.2 15.2
# 32.6 19.2
# 40 23

# %%
benimGariplİSTEM= [(10.2,15.2,23),(32.6,19.2,19),(40,23,23.4)]

# %%
for (x,y,z) in benimGariplİSTEM:
  print(z)
# Out:
# 23
# 19
# 23.4

# %%
benimSozluk = {"muz": 100, "elma": 200, "karpuz":500}

# %%
for (anahtar,deger) in benimSozluk.items():
  print(anahtar)
  print(deger)
# Out:
# muz
# 100
# elma
# 200
# karpuz
# 500
