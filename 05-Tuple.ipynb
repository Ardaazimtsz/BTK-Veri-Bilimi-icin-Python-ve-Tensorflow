# %% [markdown]
# **TUPLE**

# %%
benimListem = [1,2,3,"a",5]

# %%
benimListem[0]
# Out:
# 1

# %%
benimListem[0]=100

# %%
benimListem
# Out:
# [100, 2, 3, 'a', 5]

# %%
benimTuple = (1,2,3,"a",5)

# %%
benimTuple[0]
# Out:
# 1

# %%
#benimTuple[2]= "b"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-7-71e1351e7e8d> in <cell line: 1>()
# ----> 1 benimTuple[2]= "b"
#
# TypeError: 'tuple' object does not support item assignment

# %%
benimTuple.count("a")
# Out:
# 1

# %%
benimTuple.index(5)
# Out:
# 4
